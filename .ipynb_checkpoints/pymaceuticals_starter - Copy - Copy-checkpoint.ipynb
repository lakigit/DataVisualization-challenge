# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
#%matplotlib widget

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_data_complete = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])

# Display the data table for preview
mouse_data_complete
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
unique_mouse = mouse_data_complete['Mouse ID'].unique()
len(unique_mouse)
# Out:
# 249

# %%
mouse_data_complete[mouse_data_complete.duplicated()]['Mouse ID']
# Out:
# 137    g989
# Name: Mouse ID, dtype: object

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_ID = mouse_data_complete.loc[mouse_data_complete['Mouse ID']=="g989"]
duplicate_mouse_ID
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = mouse_data_complete.loc[mouse_data_complete['Mouse ID']!='g989']
cleaned_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
new_unique_mouse = cleaned_df['Mouse ID'].unique()
len(new_unique_mouse)
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

mean_regimen = cleaned_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()
#mean_regimen

median_regimen = cleaned_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].median()
#median_regimen

variance_regimen = cleaned_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].var()
#variance_regimen

std_regimen = cleaned_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].std()
#std_regimen

SEM_regimen = cleaned_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].sem()
#SEM_regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

summary_for_regmen = pd.DataFrame({"Mean Tumor Volume":mean_regimen,"Median Tumor Volume":median_regimen,
                                   "Tumor Volume Variance":variance_regimen,
                                  "Tumor Volume Std. Dev.":std_regimen,
                                  "Tumor Volume Std. Err.":SEM_regimen})
summary_for_regmen
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_using_aggregate = cleaned_df.groupby(['Drug Regimen']).agg({'Tumor Volume (mm3)':['mean','median','var','std','sem']})
summary_using_aggregate
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

count_regimen = cleaned_df['Drug Regimen'].value_counts()
#count_regimen

pandas_figure = count_regimen.plot(kind="bar",figsize=(7,5))
pandas_figure.set_xlabel("Drug Regimen")
pandas_figure.set_ylabel("# of observed Mouse Timepoints")
# Configure x-tick rotation
xticklabel=count_regimen.index
pandas_figure.set_xticklabels(xticklabel,rotation=90,rotation_mode="anchor",ha="right",wrap=True)

# Show plot
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
xbar = cleaned_df['Drug Regimen'].unique()
ybar = count_regimen
x_axis = np.arange(len(count_regimen))
plt.figure(figsize=(7,5))
plt.bar(x_axis, ybar, align="center")
# Configure x-tick rotation
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations,xbar,rotation=90,rotation_mode="anchor",ha="right",wrap=True)

plt.xlabel("Drug Regimen")
plt.ylabel("# of observed Mouse Timepoints")

# Show plot
plt.show()
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# gender_count = cleaned_df['Sex'].value_counts()
# gender_count
gender_count = cleaned_df.groupby(['Sex'])['Mouse ID'].count()
gender_count
pandas_pie_chart = gender_count.plot(kind='pie',autopct="%1.1f%%",startangle=180)
plt.axis("equal")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

labels = cleaned_df['Sex'].unique()
#labels

size = cleaned_df.groupby(['Sex'])['Mouse ID'].count()
#size
#colours = ['orange','blue']
plt.pie(size,labels=labels,autopct="%1.1f%%",startangle=180)
plt.axis("equal")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

group_by_ID = cleaned_df.groupby(['Mouse ID'])
group_by_ID = group_by_ID['Timepoint'].max().reset_index()
group_by_ID.columns = ['Mouse ID', 'Timepoint']

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

final_tumor_volume_df = cleaned_df.merge(group_by_ID)
final_tumor_volume_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     f932          0                45.0                 0     Ketapril
# 1     x336          0                45.0                 0     Naftisol
# 2     h428          0                45.0                 0     Ketapril
# 3     v199          0                45.0                 0     Naftisol
# 4     o848          0                45.0                 0     Stelasyn
#
#       Sex  Age_months  Weight (g)
# 0    Male          15          29
# 1  Female           4          29
# 2  Female           1          27
# 3  Female          17          29
# 4  Female          14          27

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers.     
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds
    
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
treatment_regimens   
#tumor_volume = [final_tumor_volume_df.loc[final_tumor_volume_df['Drug Regimen']==drug,'Tumor Volume (mm3)'] for drug in treatment_regimens]    
tumor_volume = []
for drug in treatment_regimens:
         volume = final_tumor_volume_df.loc[final_tumor_volume_df['Drug Regimen']==drug,'Tumor Volume (mm3)']
         tumor_volume.append(volume)
#tumor_volume            
         quartiles = volume.quantile([.25,.5,.75])
         lowerq = quartiles[0.25]
         upperq = quartiles[0.75]
         iqr = upperq-lowerq

         print(f"The lower quartile of {drug}'s is: {lowerq}")
         print(f"The upper quartile of {drug}'s is: {upperq}")
         print(f"The interquartile range of {drug}'s is: {iqr}")
         print(f"The the median of {drug}'s is: {quartiles[0.5]} ")
         lower_bound = lowerq - (1.5*iqr)
         upper_bound = upperq + (1.5*iqr)
         print(f"{drug}'s potential outliers:{lower_bound}")
         print(f"{drug}'s above outliers:{upper_bound}")
         print(f"The interquartile range of {drug}'s is: {iqr}")
         print(f"--------------------------------------------")
# Out:
# The lower quartile of Capomulin's is: 32.37735684
# The upper quartile of Capomulin's is: 40.1592203
# The interquartile range of Capomulin's is: 7.781863460000004
# The the median of Capomulin's is: 38.1251644
# Capomulin's potential outliers:20.70456164999999
# Capomulin's above outliers:51.83201549
# The interquartile range of Capomulin's is: 7.781863460000004
# --------------------------------------------
# The lower quartile of Ramicane's is: 31.56046955
# The upper quartile of Ramicane's is: 40.65900627
# The interquartile range of Ramicane's is: 9.098536719999998
# The the median of Ramicane's is: 36.56165229
# Ramicane's potential outliers:17.912664470000003
# Ramicane's above outliers:54.30681135
# The interquartile range of Ramicane's is: 9.098536719999998
# --------------------------------------------
# The lower quartile of Infubinol's is: 54.04860769
# The upper quartile of Infubinol's is: 65.52574285
# The interquartile range of Infubinol's is: 11.477135160000003
# ...

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
ax1.set_ylabel('Final Tumor Volume(mm3)')
ax1.boxplot(tumor_volume,flierprops={'marker': 'o', 'markersize': 10, 'markerfacecolor': 'red'})
ax1.set_xticklabels(treatment_regimens)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
x_axis = cleaned_df['Timepoint'].unique()
Capomulin_only = cleaned_df.loc[cleaned_df['Drug Regimen']=='Capomulin',['Tumor Volume (mm3)','Mouse ID']]
Capomulin_only
y_axix = Capomulin_only.loc[Capomulin_only['Mouse ID']=='l509',['Tumor Volume (mm3)']]
y_axix
plt.title('Capomulin Treatment of Mouse l509')
plt.xlabel('Timepoint(Days)')
plt.ylabel('Tumor Volume(mm3)')
plt.plot(x_axis,y_axix)
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
Capomulin_only2 = cleaned_df.loc[cleaned_df['Drug Regimen']=='Capomulin',['Mouse ID','Tumor Volume (mm3)','Weight (g)']]
group_by_ID_weight = Capomulin_only2.groupby(['Mouse ID','Weight (g)'])['Tumor Volume (mm3)'].mean().reset_index()
x_axis = group_by_ID_weight['Weight (g)']
y_axis = group_by_ID_weight['Tumor Volume (mm3)']
plt.xlabel('Weight(g)')
plt.ylabel('Average Tumor Volume(mm3)')
plt.scatter(x_axis,y_axis)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

correlation = st.pearsonr(x_axis,y_axis)
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
regress_values = x_axis * slope + intercept
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel('Weight(g)')
plt.ylabel('Average Tumor Volume(mm3)')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
